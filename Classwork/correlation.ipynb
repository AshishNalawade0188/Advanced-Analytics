# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("weight-height.csv")
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df_male = df[df["Gender"] == "Male"]
df_female = df[df["Gender"] == "Female"]

# %%
corr_overall = df[["Height","Weight"]].corr()
corr_male = df_male[["Height","Weight"]].corr()
corr_female = df_female[["Height","Weight"]].corr()

# %%
sp_corr_overall = df[["Height","Weight"]].corr(method="spearman")
sp_corr_male = df_male[["Height","Weight"]].corr(method="spearman")
sp_corr_female = df_female[["Height","Weight"]].corr(method="spearman")

# %%
cov_overall = df[["Height","Weight"]].cov()
cov_male = df_male[["Height","Weight"]].cov()
cov_female = df_female[["Height","Weight"]].cov()

# %%
print("Overall Correlation:\n", corr_overall, "\nOverall Spearman Correlation:\n", sp_corr_overall)
print("\nMale Correlation:\n", corr_male,"\nMale Spearman Correlation:\n", sp_corr_male)
print("\nFemale Correlation:\n", corr_female,"\nFemale Spearman Correlation:\n", sp_corr_female)
# Out:
# Overall Correlation:
#            Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000
# Overall Spearman Correlation:
#            Height    Weight
# Height  1.000000  0.925708
# Weight  0.925708  1.000000
#
# Male Correlation:
#            Height    Weight
# Height  1.000000  0.862979
# Weight  0.862979  1.000000
# Male Spearman Correlation:
#            Height    Weight
# Height  1.000000  0.848559
# Weight  0.848559  1.000000
#
# Female Correlation:
#            Height    Weight
# Height  1.000000  0.849609
# Weight  0.849609  1.000000
# Female Spearman Correlation:
#            Height    Weight
# Height  1.000000  0.836489
# Weight  0.836489  1.000000

# %%
fig, axes = plt.subplots(1, 3, figsize=(18,6))
axes[0].scatter(df["Height"], df["Weight"],color="green", alpha=0.5)
axes[0].set_title("Overall")
axes[0].set_xlabel("Height")    
axes[0].set_ylabel("Weight")

axes[1].scatter(df_male["Height"], df_male["Weight"],color="blue", alpha=0.5)
axes[1].set_title("Male")
axes[1].set_xlabel("Height")
axes[1].set_ylabel("Weight")

axes[2].scatter(df_female["Height"], df_female["Weight"],color="red", alpha=0.5)
axes[2].set_title("Female")
axes[2].set_xlabel("Height")
axes[2].set_ylabel("Weight")
# Out:
# Text(0, 0.5, 'Weight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.heatmap(corr_overall, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Overall Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Overall Correlation Heatmap')

# %%
df = pd.read_csv("Gaming_hours_vs_Performance_1000_Rows.csv")
df
# Out:
#     User_ID  Age  Gender            Occupation   Game_Type  \
# 0     U0001   21    Male  Working Professional      Action
# 1     U0002   35  Female               Student      Sports
# 2     U0003   26    Male               Student      Puzzle
# 3     U0004   32    Male  Working Professional      Action
# 4     U0005   19    Male  Working Professional      Action
# ..      ...  ...     ...                   ...         ...
# 995   U0996   23  Female  Working Professional  Simulation
# 996   U0997   30  Female               Student      Puzzle
# 997   U0998   18    Male  Working Professional      Action
# 998   U0999   25  Female               Student  Simulation
# 999   U1000   19  Female               Student    Strategy
#
#      Daily_Gaming_Hours  Weekly_Gaming_Hours Primary_Gaming_Time  Sleep_Hours  \
# 0                   4.0                 28.0             Morning          4.6
# 1                   1.0                  7.0               Night          5.4
# ...

# %%
df_category = df[["Age","Gender","Occupation"]]
df_category
# Out:
#      Age  Gender            Occupation
# 0     21    Male  Working Professional
# 1     35  Female               Student
# 2     26    Male               Student
# 3     32    Male  Working Professional
# 4     19    Male  Working Professional
# ..   ...     ...                   ...
# 995   23  Female  Working Professional
# 996   30  Female               Student
# 997   18    Male  Working Professional
# 998   25  Female               Student
# 999   19  Female               Student
#
# [1000 rows x 3 columns]

# %%
overall_correlation = df[["Age","Daily_Gaming_Hours","Weekly_Gaming_Hours", "Sleep_Hours","Stress_Level","Focus_Level","Academic_or_Work_Score","Productivity_Level"]].corr()
overall_correlation
# Out:
#                              Age  Daily_Gaming_Hours  Weekly_Gaming_Hours  \
# Age                     1.000000            0.060864             0.060864
# Daily_Gaming_Hours      0.060864            1.000000             1.000000
# Weekly_Gaming_Hours     0.060864            1.000000             1.000000
# Sleep_Hours            -0.043857            0.006285             0.006285
# Stress_Level           -0.040976            0.032357             0.032357
# Focus_Level             0.046859            0.001198             0.001198
# Academic_or_Work_Score -0.028235           -0.012049            -0.012049
# Productivity_Level     -0.031165           -0.016374            -0.016374
#
#                         Sleep_Hours  Stress_Level  Focus_Level  \
# Age                       -0.043857     -0.040976     0.046859
# Daily_Gaming_Hours         0.006285      0.032357     0.001198
# Weekly_Gaming_Hours        0.006285      0.032357     0.001198
# ...

# %%
overall_correlations = df[["Age","Weekly_Gaming_Hours", "Academic_or_Work_Score","Productivity_Level"]].corr()
overall_correlations

# %%
fig, axes = plt.subplots(2,3, figsize=(18,12))
axes[0][0].scatter(df["Weekly_Gaming_Hours"], df["Academic_or_Work_Score"],color="green", alpha=0.5)
axes[0][0].set_title("Weekly_Gaming_Hours vs Academic/Work Score")
axes[0][0].set_xlabel("Weekly_Gaming_Hours")
axes[0][0].set_ylabel("Academic/Work Score")

axes[0][1].scatter(df["Weekly_Gaming_Hours"], df["Productivity_Level"],color="blue", alpha=0.5)
axes[0][1].set_title("Weekly_Gaming_Hours vs Productivity Level")
axes[0][1].set_xlabel("Weekly_Gaming_Hours")
axes[0][1].set_ylabel("Productivity Level")

axes[0][2].scatter(df["Academic_or_Work_Score"], df["Productivity_Level"],color="red", alpha=0.5)
axes[0][2].set_title("Academic/Work Score vs Productivity Level")
axes[0][2].set_xlabel("Academic/Work Score")
axes[0][2].set_ylabel("Productivity Level")

axes[1][0].scatter(df["Age"], df["Weekly_Gaming_Hours"], color="purple", alpha=0.5)
axes[1][0].set_title("Age vs Weekly_Gaming_Hours")
axes[1][0].set_xlabel("Age")
axes[1][0].set_ylabel("Weekly_Gaming_Hours")

axes[1][1].scatter(df["Age"], df["Academic_or_Work_Score"], color="orange", alpha=0.5)
axes[1][1].set_title("Age vs Academic/Work Score")
axes[1][1].set_xlabel("Age")
axes[1][1].set_ylabel("Academic/Work Score")

axes[1][2].scatter(df["Age"], df["Productivity_Level"], color="brown", alpha=0.5)
axes[1][2].set_title("Age vs Productivity Level")
axes[1][2].set_xlabel("Age")
axes[1][2].set_ylabel("Productivity Level")

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.heatmap(overall_correlation, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Overall Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Overall Correlation Heatmap')

# %%
plt.figure(figsize=(10,5))
sns.heatmap(overall_correlation, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Overall Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Overall Correlation Heatmap')

# %%
fig, axes = plt.subplots(3,2, figsize=(18,12))
axes[0][0].scatter(df["Weekly_Gaming_Hours"], df["Daily_Gaming_Hours"],color="green", alpha=0.5)
axes[0][0].set_title("Weekly_Gaming_Hours vs Daily_Gaming_Hours")
axes[0][0].set_xlabel("Weekly_Gaming_Hours")
axes[0][0].set_ylabel("Daily_Gaming_Hours")

axes[0][1].scatter(df["Academic_or_Work_Score"], df["Productivity_Level"],color="blue", alpha=0.5)
axes[0][1].set_title("Academic_or_Work_Score vs Productivity Level")
axes[0][1].set_xlabel("Academic_or_Work_Score")
axes[0][1].set_ylabel("Productivity Level")


axes[1][0].scatter(df["Daily_Gaming_Hours"], df["Academic_or_Work_Score"], color="red", alpha=0.5)
axes[1][0].set_title("Daily_Gaming_Hours vs Academic_or_Work_Score")
axes[1][0].set_xlabel("Daily_Gaming_Hours")
axes[1][0].set_ylabel("Academic_or_Work_Score")

axes[1][1].scatter(df["Daily_Gaming_Hours"], df["Productivity_Level"], color="yellow", alpha=0.5)
axes[1][1].set_title("Daily_Gaming_Hours vs Productivity_Level")
axes[1][1].set_xlabel("Daily_Gaming_Hours")
axes[1][1].set_ylabel("Productivity_Level")


axes[2][0].scatter(df["Weekly_Gaming_Hours"], df["Academic_or_Work_Score"], color="black", alpha=0.5)
axes[2][0].set_title("Weekly_Gaming_Hours vs Academic_or_Work_Score")
axes[2][0].set_xlabel("Weekly_Gaming_Hours")
axes[2][0].set_ylabel("Academic_or_Work_Score")

axes[2][1].scatter(df["Weekly_Gaming_Hours"], df["Productivity_Level"], color="orange", alpha=0.5)
axes[2][1].set_title("Weekly_Gaming_Hours vs Productivity_Level")
axes[2][1].set_xlabel("Weekly_Gaming_Hours")
axes[2][1].set_ylabel("Productivity_Level")

plt.tight_layout()
plt.show()

# %%
overall_correlation = df[["Daily_Gaming_Hours","Weekly_Gaming_Hours","Academic_or_Work_Score","Productivity_Level"]].corr()
overall_correlation
plt.figure(figsize=(10,5))
sns.heatmap(overall_correlation, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Overall Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Overall Correlation Heatmap')
