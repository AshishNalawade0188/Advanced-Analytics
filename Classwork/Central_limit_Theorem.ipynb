# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np
df = pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
glucose = df["Glucose"]
shapiro_test = stats.shapiro(df["Glucose"])
print("pvalue:",shapiro_test.pvalue)
alpha = 0.05
if shapiro_test.pvalue > alpha:
    print("Data is normally distributed")
else:
    print("data is not normally distributed")
    

stats.probplot(glucose,dist="norm",plot=plt)
plt.title("Glucose")
plt.xlabel("Normal destribution")
plt.ylabel("pvalue")
plt.grid(True)
plt.show()
# Out:
# pvalue: 1.9863474999979633e-11
# data is not normally distributed

# %%
samples_means = []
n_samples = 100
sample_size = 30

for _ in range(n_samples):
    sample = df["Glucose"].sample(n = sample_size,replace=True)
    samples_means.append(sample.mean())
    
samples_means
# Out:
# [np.float64(122.33333333333333),
#  np.float64(114.13333333333334),
#  np.float64(115.93333333333334),
#  np.float64(118.73333333333333),
#  np.float64(117.1),
#  np.float64(124.9),
#  np.float64(120.43333333333334),
#  np.float64(122.56666666666666),
#  np.float64(129.36666666666667),
#  np.float64(115.23333333333333),
#  np.float64(123.76666666666667),
#  np.float64(117.73333333333333),
#  np.float64(122.2),
#  np.float64(128.23333333333332),
#  np.float64(124.53333333333333),
#  np.float64(131.76666666666668),
#  np.float64(112.86666666666666),
#  np.float64(119.66666666666667),
#  np.float64(106.33333333333333),
#  np.float64(122.53333333333333),
#  np.float64(120.86666666666666),
#  np.float64(127.73333333333333),
#  np.float64(127.7),
#  np.float64(121.5),
#  np.float64(116.63333333333334),
#  np.float64(120.36666666666666),
#  np.float64(120.76666666666667),
#  np.float64(113.7),
#  np.float64(123.83333333333333),
#  np.float64(125.43333333333334),
#  np.float64(114.9),
# ...

# %%
plt.hist(samples_means,bins=30,edgecolor="k",alpha=0.7)
plt.title("Distrobution of Sample means (n=30)")
plt.xlabel("sample mean")
plt.ylabel("Frequency")
plt.show()

# %%
shapiro_test = stats.shapiro(samples_means)
print("pvalue:",shapiro_test.pvalue)
alpha = 0.05
if shapiro_test.pvalue > alpha:
    print("Data is normally distributed")
else:
    print("data is not normally distributed")
# Out:
# pvalue: 0.22747224792083115
# Data is normally distributed

# %%
stats.probplot(samples_means,dist="norm",plot=plt)
plt.title("Q-Q plot of people mean")
plt.show()
