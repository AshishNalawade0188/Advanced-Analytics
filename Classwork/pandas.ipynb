# %%
import numpy as np 
import pandas as pd

# %%
arr = np.array([56,87,73])
print(arr)
s = pd.Series([100,200,300],index=['a','b','c'])
print(s)
# Out:
# [56 87 73]
# a    100
# b    200
# c    300
# dtype: int64

# %%
s1=pd.Series(data=[100,200,300],index=['ashish','bakula','chetan'])
print(s1)
# Out:
# ashish    100
# bakula    200
# chetan    300
# dtype: int64

# %%
print(s1["ashish"])
# Out:
# 100

# %%
print(s.iloc[1])
# Out:
# 200

# %%
df=pd.DataFrame({"sales":[100,200,300],"profit":[456123,321654,4102563]},index=["acts","IACDS","knowit"])
print(df)
# Out:
#         sales   profit
# acts      100   456123
# IACDS     200   321654
# knowit    300  4102563

# %%
print(df.head(2))
# Out:
#        sales  profit
# acts     100  456123
# IACDS    200  321654

# %%
print(df.tail(2))
# Out:
#         sales   profit
# IACDS     200   321654
# knowit    300  4102563

# %%
print(df.shape)
# Out:
# (3, 2)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 3 entries, acts to knowit
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sales   3 non-null      int64
#  1   profit  3 non-null      int64
# dtypes: int64(2)
# memory usage: 72.0+ bytes
# None

# %%
print(df.columns)
# Out:
# Index(['sales', 'profit'], dtype='str')
